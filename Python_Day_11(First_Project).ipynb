# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Choudhry/Python-Learning/blob/main/Python_Day_11(First_Project).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **QUIZ** **GAME**

# %%
q = ["Which programming language is known as the snake?"]
print(q)
print("Options: A) Java, B) Python, C) C++, D) Swift")
a = input()
if (a=="B"):
  print("CORRECT, You got 100 points")
  b = ["2) What does HTML stand for?", "3) Which company created the Android operating system?"]
  print(b)
  print("Options: A) HyperText Markup Language, B) High Tech Modern Language, C) HyperTransfer Machine Language, D) None of the above")
  K = input()
  if (K == "A"):
   print("CORRECT, You got 100 points (TOTAL=200)")
  else:
   print("Incorrect, you got 0 Points ")
  print("Options: A) Apple, B) Microsoft, C) Google, D) IBM")
  j = input("Give answer of 3rd question: ")
  if (j == "C"):
   print("CORRECT, You got 100 points (TOTAL=300)")
   print("You Win")
else:
  print("Incorrect, you got 0 Points ")
  print("You Lost")
# Out:
# ['Which programming language is known as the snake?']
# Options: A) Java, B) Python, C) C++, D) Swift
# B
# CORRECT, You got 100 points
# ['2) What does HTML stand for?', '3) Which company created the Android operating system?']
# Options: A) HyperText Markup Language, B) High Tech Modern Language, C) HyperTransfer Machine Language, D) None of the above
# A
# CORRECT, You got 100 points (TOTAL=200)
# Options: A) Apple, B) Microsoft, C) Google, D) IBM
# Give answer of 3rd question: C
# CORRECT, You got 100 points (TOTAL=300)
# You Win
