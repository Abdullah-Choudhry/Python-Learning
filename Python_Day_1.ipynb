# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Choudhry/Python-Learning/blob/main/Python_Day_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World,Bacha")
print("5,6")
print("5 and 6 are different numbers you know?")
print("ALL HEROS ARE NOT HEROS")
print("Yes!, 7" , 7)
print(6*6)
print(8/4)
# Out:
# Hello World,Bacha
# 5,6
# 5 and 6 are different numbers you know?
# ALL HEROS ARE NOT HEROS
# Yes!, 7 7
# 36
# 2.0
