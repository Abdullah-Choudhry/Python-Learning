# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Choudhry/Python-Learning/blob/main/Python_Day_010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Tuples**

# %%
#same a lists but these are immutable
tup = (4, 5, 8, 3)
print(type(tup))
print(tup)
if 5 in tup:
  print("Present")
print(tup[0])
tup2 = tup[1:3]
print(tup2)
# Out:
# <class 'tuple'>
# (4, 5, 8, 3)
# Present
# 4
# (5, 8)

# %% [markdown]
# **Tuples** **Methods**

# %%
tuple = (1, 2, 3, 1, 2, 1, 6,)
tuple2 = (8, 9)
c =(tuple + tuple2)
print(c)
r = tuple.count(1)
print(r)
r =tuple.index(3)
print(r)
r = tuple.index(1, 1, 4)
print(r)
# Out:
# (1, 2, 3, 1, 2, 1, 6, 8, 9)
# 3
# 2
# 3
