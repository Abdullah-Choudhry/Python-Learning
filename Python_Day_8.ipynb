# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Choudhry/Python-Learning/blob/main/Python_Day_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Functions**

# %%
def calculateGmean (a,b):
  mean = (a*b)/(a+b)
  print(mean)

def isgreater (a,b):
  if (a>b):
    print("a is greater")
  else :
    print("b is greater")

a = 8
b = 9
isgreater (a,b)
calculateGmean(a,b)
# Gmean1 = (a*b)/(a+b)
# print(Gmean1)
c = 6
d = 7
isgreater (c,d)
calculateGmean(c,d)
# Gmean2 = (c*d)/(c+d)
# print(Gmean2)
def islesser(a,b):
  pass
# Out:
# b is greater
# 4.235294117647059
# b is greater
# 3.230769230769231

# %% [markdown]
# **Function** **Arguments**

# %%
def average (a = 9, b = 3):             # Default arguuments
  print("Average is ", + (a+b)/2)

average(b = 6)
def name(fname, mname ="javed", lname = "Ch"):
  print("Hello", fname, mname, lname)

name("M", "Abdullah")
def multiply(c, d = 10):
  print(c*d)

multiply(c=2)                      #c is required argument

#variable length argument
def average(*numbers):             #tuple   (numbers)
   sum = 0
   for i in numbers:
    sum = sum + i
   print("Average is", sum/len(numbers))
   return sum/len(numbers)  # for storing in c
average(8 , 9 , 7 , 5)
c = average(8 , 9 , 7 , 5)
# Out:
# Average is  7.5
# Hello M Abdullah Ch
# 20
# Average is 7.25
# Average is 7.25
