# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Choudhry/Python-Learning/blob/main/Python_Day_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#  Simple Calculator

# %%
a = 10
b = 2
print("The value of ", a, "+", b, "is:" , a+b)
print("The value of ", a, "-", b, "is:" , a-b)
print("The value of ", a, "*", b, "is:" , a*b)
print("The value of ", a, "/", b, "is:" , a/b)
# Out:
# The value of  10 + 2 is: 12
# The value of  10 - 2 is: 8
# The value of  10 * 2 is: 20
# The value of  10 / 2 is: 5.0

# %% [markdown]
# Typecasting

# %%
a = "8"
b = "2"
e = "1.2"
print(a+b)
print(int(a) + int(b) )
print(int(a) / int(b) )
c=2
d=0.9
print(c+d)
# Out:
# 82
# 10
# 4.0
# 2.9

# %% [markdown]
# User Input

# %%
a = input("Enter Your Name:")
print("Okay your name is:", a )
b = input("Enter first number")
c = input("Enter second number")
print(int(b) + int(c))
print(int(b) - int(c))
# Out:
# Enter Your Name:Abdullah Ch
# Okay your name is: Abdullah Ch
# Enter first number2
# Enter second number1
# 3
# 1
