# %% [markdown]
# Escape Sequences

# %%
print('Hello')
'''Yes it is true'''
print("He is a good boy \nand also talented.")
# Dont remove this kindly
print('Yes this is \"Python\" language')
"""this is coding"""
print("Abdullah", 8, 6,  sep="~", end="55\n")
print("Pakistan")
# Out:
# Hello
# He is a good boy
# and also talented.
# Yes this is "Python" language
# Abdullah~8~655
# Pakistan

# %% [markdown]
# Variables

# %%
a=2323445
print(a)
b="Abdullah"
print(b)
c = 8
d = 2
print(c*d)
e = True
print(e)
print("The type of a is", type(a))
print("The type  of b is", type(b))
print("The type of c is", type(c))
print("The type of d is", type(d))
print("The type of e is", type(e))
# Out:
# 2323445
# Abdullah
# 16
# True
# The type of a is <class 'int'>
# The type  of b is <class 'str'>
# The type of c is <class 'int'>
# The type of d is <class 'int'>
# The type of e is <class 'bool'>

# %% [markdown]
# Operators

# %%
print(5+5)
print(5-1)
print(5*2)
print(7/3)
print(7//3)
print(5**3)
print(10%3)
# Out:
# 10
# 4
# 10
# 2.3333333333333335
# 2
# 125
# 1
