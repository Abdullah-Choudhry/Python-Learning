# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Choudhry/Python-Learning/blob/main/Python_Day_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **If** **Else**

# %%
a = int(input("Enter your age: "))
if(a>18):
  print("You can drive")
  print("YES")
elif(a==18):
  print("Yes you can drive")
else:
  print("You can not drive")
budget = int(input("BUDGET?: "))
mobile = 15000
if(budget>mobile):
    print("you can buy mobile")
else:
    print("you cannot buy.")
# Out:
# Enter your age: 22
# You can drive
# YES
# BUDGET?: 10000
# you cannot buy.
