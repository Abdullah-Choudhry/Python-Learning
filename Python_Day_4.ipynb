# %% [markdown]
# <a href="https://colab.research.google.com/github/Abdullah-Choudhry/Python-Learning/blob/main/Python_Day_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Strings**

# %%
print("Hello")
name = "Ali"
print(" Yes "+name)
a = '''okay
now tell me
the truth'''
print(a)
print(name[0])
print(name[1])
print(name[2])
# print(name[3])  #index error
# Out:
# Hello
#  Yes Ali
# okay
# now tell me
# the truth
# A
# l
# i

# %% [markdown]
# **String** **Methods**

# %%
fruit = 'apple'
length = len(fruit)
print(length)
print(fruit[0])
print(fruit[0:2])  #include 0 but not 2
print(fruit[:3])
print(fruit[-2:-1])
print(fruit[-3:3])

a = "Helloo 0111"
print(len(a))
print(a.endswith("lo",0,5))
print((a.center(20)))
print(a)
print(a.upper())
print(a.lower())
print(a.endswith("1"))
print(a.count("1"))
print(a.rstrip("1"))
print(a.split(" "))
print(a.replace("Helloo" , "Okay"))
print(a.upper())
heading = "story of a farmer"
print(heading.capitalize())
b = "yesokay0"
print(b.isalnum())
print(b.islower())
c = "OkayOkay"
print(b.isalnum())
d = "introduction To biology"
print(d.title())
print(d.istitle())
print(d.startswith("in"))
print(d.swapcase())
# Out:
# 5
# a
# ap
# app
# l
# p
# 11
# True
#     Helloo 0111
# Helloo 0111
# HELLOO 0111
# helloo 0111
# True
# 3
# Helloo 0
# ['Helloo', '0111']
# Okay 0111
# HELLOO 0111
# Story of a farmer
# True
# True
# True
# Introduction To Biology
# False
# True
# INTRODUCTION tO BIOLOGY
